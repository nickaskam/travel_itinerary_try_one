# %%
#This will be the project that takes longer than the other one

# %% [markdown]
# Travel Planner System - Make a system that allows users to put together their own little travel itinerary and keep track of the airline / hotel arrangements, points of interest, budget and schedule.

# %%
class Flight_plans:
    def __init__(self):
        self.depart_airline = " "
        self.depart_flight_gate = " "
        self.depart_flight_time = " "
        self.return_airline = " "
        self.return_flight_gate = " "
        self.return_flight_time = " "

class Hotel_plans:
    def __init__(self):
        self.hotel_name = " "
        self.hotel_address = " "
        self.hotel_confirmation_id = " "

class Points_Of_Interest:
    def __init__(self):
        self.points_of_interest1 = []
        self.city_name = " "

def show_departing_flight():
    Flight_plans.depart_airline = "American Airlines"
    Flight_plans.depart_flight_gate = "3B"
    Flight_plans.depart_flight_time = "10:00 AM"
    print('Your departing flight is on ' + Flight_plans.depart_airline + ', Gate: ' + Flight_plans.depart_flight_gate + ', at ' + Flight_plans.depart_flight_time)
    
def show_return_flight():
    Flight_plans.return_airline = "Southwest Airlines"
    Flight_plans.return_flight_gate = "4A"
    Flight_plans.return_flight_time = "8:00 PM"
    print('Your returning flight is on ' + Flight_plans.return_airline + ', Gate: ' + Flight_plans.return_flight_gate + ', at ' + Flight_plans.return_flight_time)

def show_flightplans():
    print("\nFlight Information:")
    show_departing_flight()
    show_return_flight()

def input_hotel_plans():
    Hotel_plans.hotel_name = "JW Marriott"
    Hotel_plans.hotel_address = "110 East 2nd Street, Austin, Texas 78701"
    Hotel_plans.hotel_confirmation_id = "8573657372A"
    print("You are staying at the " + Hotel_plans.hotel_name + ' at ' + Hotel_plans.hotel_address + ". Confirmation ID: " + Hotel_plans.hotel_confirmation_id)
    
def show_hotelplans():
    print("\nHotel Information:")
    input_hotel_plans()

def dallas():
    Points_Of_Interest.city_name = "Dallas"
    Points_Of_Interest.points_of_interest1 = ["reunion tower", "sixth floor museum", "george bush library"]
    print("\nPoints of Interest for the city of: " + Points_Of_Interest.city_name)
    for attraction in Points_Of_Interest.points_of_interest1:
        print(attraction)
            
def austin():
    Points_Of_Interest.city_name = "Austin"
    Points_Of_Interest.points_of_interest1 = ["zilker park", "lady bird lake", "state capital"]
    for attraction in Points_Of_Interest.points_of_interest1:
        print(attraction)
            
def houston():
    Points_Of_Interest.city_name = "Houston"
    Points_Of_Interest.points_of_interest1 = ["space center", "houston zoo", "houston aquarium"]
    for attraction in Points_Of_Interest.points_of_interest1:
        print(attraction)
    
def input_pointsofinterest():
    print("\nThird question: ")
    global city_selection
    city_selection = input("\nWhich city are you going to? ")
    print("Thank you!")
    
def show_pointsofinterest():
    if city_selection[:6].lower() == "dallas":
        dallas()
    elif city_selection[:6].lower() == "austin":
        print("\nPoints of Interest for the city of: " + city_selection)
        austin()
    elif city_selection[:7].lower() == "houston":
        print("\nPoints of Interest for the city of: " + city_selection)
        houston()
    else:
        print("The city you've selected has no current points of interest")
    
def input_budget():
    while True: 
        try: 
            print("One quick question before we get started:")
            global budget
            budget = float(input("What is your budget for this trip? (in $) "))
        except ValueError:
            print("Please enter a number")
        else: 
            print("Thank you!")
            break
    
    while True: 
        try:
            print("Second question:")
            global nights_staying
            nights_staying = int(input("How many nights are you staying?"))
        except ValueError:
            print("Please enter an integer")
        else: 
            print("Thank you!")
            break

def show_budget():
    print("\nBudget Information: ")
    print("You have budgeted: $", budget, "for this trip.")
    print("You are staying for ",nights_staying,"nights which means you can spend $",budget/nights_staying,"per day")
    
def set_variables():
    global flightplans
    flightplans = Flight_plans()
    global hotelplans
    hotelplans = Hotel_plans()
    global pointsofinterest
    pointsofinterest = Points_Of_Interest()
    print("\nWelcome to your travel itinerary! \nHere's the information in your plan so far:")
    
def show_information():
    show_flightplans()
    show_hotelplans()
    show_budget()
    show_pointsofinterest()
    
def input_functions():
    input_budget()
    input_pointsofinterest()
    
input_functions()
set_variables()
show_information()
print("\nCopy and paste this to a Google doc for future reference")
# Out:
# One quick question before we get started:
# What is your budget for this trip? (in $) 780
# Thank you!
# Second question:
# How many nights are you staying?4
# Thank you!
#
# Third question:
#
# Which city are you going to? houston
# Thank you!
#
# Welcome to your travel itinerary!
# Here's the information in your plan so far:
#
# Flight Information:
# Your departing flight is on American Airlines, Gate: 3B, at 10:00 AM
# Your returning flight is on Southwest Airlines, Gate: 4A, at 8:00 PM
#
# Hotel Information:
# You are staying at the JW Marriott at 110 East 2nd Street, Austin, Texas 78701. Confirmation ID: 8573657372A
#
# Budget Information:
# You have budgeted: $ 780.0 for this trip.
# You are staying for  4 nights which means you can spend $ 195.0 per day
#
# Points of Interest for the city of: houston
# space center
# houston zoo
# houston aquarium
#
# Copy and paste this to a Google doc for future reference
